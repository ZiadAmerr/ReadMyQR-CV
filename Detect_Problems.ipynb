# %%
import os
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
def plot_histogram(image):
    hist = cv2.calcHist([image], [0], None, [256], [0, 256])
    plt.plot(hist)
    plt.title("Histogram")
    plt.xlabel("Pixel value")
    plt.ylabel("Frequency")
    plt.show()

def unique_pixel_values(image):
    # Flatten the image to a 1D array
    flattened_image = image.ravel()

    # Find unique pixel values and their counts
    unique_values, counts = np.unique(flattened_image, return_counts=True)

    # Create a dictionary to store unique pixel values and their counts
    pixel_counts = dict(zip(unique_values, counts))

    return pixel_counts

# %%
# Define the path to the folder containing the images
folder_path = "test_cases"

# Initialize an empty dictionary to store the images
image_dict = {}
target_size = (1012, 1012)
# Iterate over each file in the folder
for filename in os.listdir(folder_path):
      # Open the image using cv2
      image_path = os.path.join(folder_path, filename)
      image = cv2.imread(image_path,  cv2.IMREAD_GRAYSCALE)
      image = cv2.resize(image, target_size)

      # Add the image to the dictionary with the filename as the key
      image_dict[filename] = (image, unique_pixel_values(image))

# Sort the dictionary keys (filenames)
sorted_keys = sorted(image_dict.keys())

# Create a new dictionary with sorted keys
sorted_image_dict = {key: image_dict[key] for key in sorted_keys}

# Iterate over the sorted dictionary and print each key-value pair
for filename, pair in sorted_image_dict.items():
    print(f"Filename: {filename}")
    plt.figure()
    plt.imshow(pair[0], cmap = 'gray')
    plt.title(filename)
    plt.axis('off')
    plt.show()
    print("-----------------------------")
# Out:
# Filename: 01-Getting-started.png
# -----------------------------
# Filename: 02-Matsawar-3edel-ya3am.png
# -----------------------------
# Filename: 03-Leffy-bina-ya-donya.png
# -----------------------------
# Filename: 04-Black-mirror.png
# -----------------------------
# Filename: 05-Caesar-cipher.png
# -----------------------------
# Filename: 06-Railfence-cipher.png
# -----------------------------
# Filename: 07-THE-MIGHTY-FINGER.png
# -----------------------------
# Filename: 08-Compresso-Espresso.png
# -----------------------------
# Filename: 09-My-phone-fell-while-taking-this-one-...-or-did-it.png
# -----------------------------
# Filename: 10-Gone-With-The-Wind.png
# -----------------------------
# Filename: 11-weewooweewooweewoo.png
# -----------------------------
# Filename: 12-mal7-w-felfel.png
# -----------------------------
# Filename: 13-2el-noor-2ata3.png
# -----------------------------
# Filename: 14-BANANAAA!!!.png
# -----------------------------
# Filename: 15-beast-mode-computer-vision-(this-one-is-from-wikipedia).jpg
# -----------------------------
# Filename: 16-V3-QR-Code...-can-you-do-it.png
# -----------------------------

# %%
# Plot histogram for each image
for name, pair in sorted_image_dict.items():
    print(f"{name}:")
    plot_histogram(pair[0])
    print(pair[1])
# Out:
# 01-Getting-started.png:
# {0: 437536, 255: 586608}
# 02-Matsawar-3edel-ya3am.png:
# {0: 396493, 1: 148, 2: 135, 3: 131, 4: 126, 5: 129, 6: 117, 7: 123, 8: 106, 9: 101, 10: 114, 11: 102, 12: 98, 13: 104, 14: 96, 15: 96, 16: 174, 17: 109, 18: 88, 19: 84, 20: 91, 21: 80, 22: 86, 23: 83, 24: 92, 25: 80, 26: 81, 27: 88, 28: 80, 29: 76, 30: 82, 31: 91, 32: 74, 33: 75, 34: 71, 
5, 160: 1043, 163: 3, 164: 2, 165: 2, 166: 3, 167: 23, 168: 377, 169: 5, 171: 5, 172: 2, 175: 1577, 177: 4, 178: 1, 179: 4, 180: 2, 181: 1, 182: 821, 183: 2, 184: 1, 185: 3, 186: 4, 187: 3, 188: 5, 189: 284, 190: 851, 191: 2, 192: 4, 193: 3, 195: 3, 196: 1, 197: 647, 198: 3, 199: 2, 201: 1, 202: 1, 203: 2, 204: 993, 205: 3, 206: 2, 207: 3, 210: 1, 211: 215, 212: 237, 213: 2, 214: 2, 215: 3, 217: 2, 219: 1105, 220: 1, 221: 2, 223: 8, 224: 2, 225: 2, 226: 931, 227: 1, 228: 5, 229: 3, 230: 5, 231: 1, 232: 1, 233: 2664, 234: 4, 235: 2, 236: 7, 237: 2, 238: 12, 239: 7, 240: 3, 241: 931, 242: 2, 243: 3, 244: 4, 245: 4, 246: 3, 247: 4, 248: 1171, 249: 6, 250: 4, 251: 4, 252: 9, 253: 9, 254: 5, 255: 533801}

# %%
def filter_images_by_metric(image_dict):
    filtered_dict = {}

    for image_name, (image, pixel_counts) in image_dict.items():
        total_pixels = sum(pixel_counts.values())
        zero_pixels = pixel_counts.get(0, 0)
        white_pixels = pixel_counts.get(255, 0)
        percentage_zero_or_white = (zero_pixels + white_pixels) / total_pixels * 100

        if percentage_zero_or_white >= 92:
            filtered_dict[image_name] = (image, pixel_counts)

    return filtered_dict

# Example usage:
filtered_images = filter_images_by_metric(sorted_image_dict)

for key in filtered_images.keys():
    if key in sorted_image_dict and sorted_image_dict[key] == filtered_images[key]:
        del sorted_image_dict[key]

# %%
# Plot histogram for each image
for name, pair in filtered_images.items():
    print(f"{name}:")
    # plot_histogram(pair[0])
    # print(pair[1])

print("------------------------")

for name, pair in sorted_image_dict.items():
    print(f"{name}:")
    # plot_histogram(pair[0])
    # print(pair[1])
# Out:
# 01-Getting-started.png:
# 02-Matsawar-3edel-ya3am.png:
# 03-Leffy-bina-ya-donya.png:
# 05-Caesar-cipher.png:
# 06-Railfence-cipher.png:
# 16-V3-QR-Code...-can-you-do-it.png:
# ------------------------
# 04-Black-mirror.png:
# 07-THE-MIGHTY-FINGER.png:
# 08-Compresso-Espresso.png:
# 09-My-phone-fell-while-taking-this-one-...-or-did-it.png:
# 10-Gone-With-The-Wind.png:
# 11-weewooweewooweewoo.png:
# 12-mal7-w-felfel.png:
# 13-2el-noor-2ata3.png:
# 14-BANANAAA!!!.png:
# 15-beast-mode-computer-vision-(this-one-is-from-wikipedia).jpg:

# %%
nominator = 0
denominator = 0
means = []
for name, (_, pixel_values) in sorted_image_dict.items():
  for value, number_of_pixels in pixel_values.items():
    nominator += value * number_of_pixels
    denominator += number_of_pixels
  mean = nominator/denominator
  print(f"{name}: {mean}")
  nominator = 0
  denominator = 0
  means.append((name, mean))
# Out:
# 04-Black-mirror.png: 30.001056492055806
# 07-THE-MIGHTY-FINGER.png: 150.5774764095674
# 08-Compresso-Espresso.png: 199.60166929650518
# 09-My-phone-fell-while-taking-this-one-...-or-did-it.png: 123.43554226749363
# 10-Gone-With-The-Wind.png: 201.35073485759816
# 11-weewooweewooweewoo.png: 129.28739708478494
# 12-mal7-w-felfel.png: 128.0226257245075
# 13-2el-noor-2ata3.png: 2.202481291693356
# 14-BANANAAA!!!.png: 245.49655614835413
# 15-beast-mode-computer-vision-(this-one-is-from-wikipedia).jpg: 157.90590776297083

# %%
hist_equlize = {}
for (name, mean) in means:
  if mean < 35 or mean > 195:
    if name in sorted_image_dict:
        # Add the key-value pair to the new dictionary
        hist_equlize[name] = sorted_image_dict[name]
        # Remove the key-value pair from the original dictionary
        del sorted_image_dict[name]

print("sorted_image_dict Dictionary after removal:", sorted_image_dict.keys())
print("hist_equlize Dictionary:", hist_equlize.keys())
# Out:
# Original Dictionary after removal: dict_keys(['07-THE-MIGHTY-FINGER.png', '09-My-phone-fell-while-taking-this-one-...-or-did-it.png', '11-weewooweewooweewoo.png', '12-mal7-w-felfel.png', '15-beast-mode-computer-vision-(this-one-is-from-wikipedia).jpg'])
# New Dictionary: dict_keys(['04-Black-mirror.png', '08-Compresso-Espresso.png', '10-Gone-With-The-Wind.png', '13-2el-noor-2ata3.png', '14-BANANAAA!!!.png'])

# %%
for name, (image, _) in hist_equlize.items():
  equalized_image = cv2.equalizeHist(image)
  _, equalized_image = cv2.threshold(equalized_image, 100, 255, cv2.THRESH_BINARY)
  new_pixel_values = unique_pixel_values(equalized_image)
   # fixing the inverted black mirror image, please note that it it rotated so you have to use a rotation detection algorithm.
   # also note that the other three image needs to be fixed with some dialation then they are ready for detection.
   # you have to solutions:
   # first you separate the black mirror image and apply rotation algorithm on it. thus there will be no need for running rotation detection on the others.
   # second you try to fix all images and run the rotation detection on all of them.
  if new_pixel_values[0] > new_pixel_values[255]:
    equalized_image = cv2.bitwise_not(equalized_image)

  print(f"{name}:")
  plt.figure()
  plt.imshow(equalized_image, cmap = 'gray')
  plt.title(name)
  plt.axis('off')
  plt.show()
  print("-----------------------------")
  plot_histogram(equalized_image)
# Out:
# 04-Black-mirror.png:
# -----------------------------
# 08-Compresso-Espresso.png:
# -----------------------------
# 10-Gone-With-The-Wind.png:
# -----------------------------
# 13-2el-noor-2ata3.png:
# -----------------------------
# 14-BANANAAA!!!.png:
# -----------------------------

# %%
# Plot histogram for each image
for name, (image, pixel_values) in sorted_image_dict.items():
    print(f"{name}:")
    # Compute the Fourier Transform
    f_transform = np.fft.fft2(image)
    f_transform_shifted = np.fft.fftshift(f_transform)
    magnitude_spectrum = 20 * np.log(np.abs(f_transform_shifted))

    # Display the original image and its Fourier Transform
    plt.subplot(121), plt.imshow(image, cmap='gray')
    plt.title('Input Image'), plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(magnitude_spectrum, cmap='gray')
    plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
    plt.show()
    # plot_histogram(image)
    # print(pixel_values)
# Out:
# 07-THE-MIGHTY-FINGER.png:
# 09-My-phone-fell-while-taking-this-one-...-or-did-it.png:
# 11-weewooweewooweewoo.png:
# 12-mal7-w-felfel.png:
# 15-beast-mode-computer-vision-(this-one-is-from-wikipedia).jpg:
